# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\pudur\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("spain_real_data_modified - sheet1 (1).csv")

# %%
df
# Out:
#             Date           League  HomeTeam   AwayTeam  FTHG  FTAG FTR  HST  \
# 0     2022-04-16    Spain La Liga    Alaves  Vallecano     1     0   H    5
# 1     2022-03-19    Spain La Liga    Alaves    Granada     2     3   A    6
# 2     2022-03-04    Spain La Liga    Alaves    Sevilla     0     0   D    2
# 3     2022-02-13    Spain La Liga    Alaves   Valencia     2     1   H    5
# 4     2022-01-23    Spain La Liga    Alaves  Barcelona     0     1   A    2
# ...          ...              ...       ...        ...   ...   ...  ..  ...
# 4632  2010-11-14  Spanish La Liga  Zaragoza    Sevilla     1     2   A    2
# 4633  2010-10-23  Spanish La Liga  Zaragoza  Barcelona     0     2   A    4
# 4634  2010-09-22  Spanish La Liga  Zaragoza   Hercules     0     0   D    5
# 4635  2010-07-11  Spanish La Liga  Zaragoza   Mallorca     3     2   H    3
# 4636  2010-02-10  Spanish La Liga  Zaragoza   Sp Gijon     2     2   D    4
#
# ...

# %%
df.head()
# Out:
#          Date         League HomeTeam   AwayTeam  FTHG  FTAG FTR  HST  AST  \
# 0  2022-04-16  Spain La Liga   Alaves  Vallecano     1     0   H    5    3
# 1  2022-03-19  Spain La Liga   Alaves    Granada     2     3   A    6    3
# 2  2022-03-04  Spain La Liga   Alaves    Sevilla     0     0   D    2    4
# 3  2022-02-13  Spain La Liga   Alaves   Valencia     2     1   H    5    4
# 4  2022-01-23  Spain La Liga   Alaves  Barcelona     0     1   A    2    4
#
#    HomeTeamLP  AwayTeamLP  HTFormPts  ATFormPts  HTEloRatings  ATEloRatings  \
# 0          19          11          1          3   1584.629028   1616.029785
# 1          19          18          5          1   1600.041260   1620.776367
# 2          19           3          4          9   1591.165649   1840.536499
# 3          19          10          2          2   1579.245483   1702.438721
# 4          19           2          2          9   1591.381836   1830.984985
#
#    numbers  Avg_HST  Avg_AST
# ...

# %%
df.tail()
# Out:
#             Date           League  HomeTeam   AwayTeam  FTHG  FTAG FTR  HST  \
# 4632  2010-11-14  Spanish La Liga  Zaragoza    Sevilla     1     2   A    2
# 4633  2010-10-23  Spanish La Liga  Zaragoza  Barcelona     0     2   A    4
# 4634  2010-09-22  Spanish La Liga  Zaragoza   Hercules     0     0   D    5
# 4635  2010-07-11  Spanish La Liga  Zaragoza   Mallorca     3     2   H    3
# 4636  2010-02-10  Spanish La Liga  Zaragoza   Sp Gijon     2     2   D    4
#
#       AST  HomeTeamLP  AwayTeamLP  HTFormPts  ATFormPts  HTEloRatings  \
# 4632    2          13           5          5          9   1641.602905
# 4633   10          13           1          2         13   1636.762817
# 4634    4          13          19          2          3   1651.854126
# 4635    4          13          17          2         10   1685.929443
# 4636    5          13          10          2          4   1676.301880
#
#       ATEloRatings  numbers  Avg_HST   Avg_AST
# ...

# %%
df.columns
# Out:
# Index(['Date', 'League', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST',
#        'AST', 'HomeTeamLP', 'AwayTeamLP', 'HTFormPts', 'ATFormPts',
#        'HTEloRatings', 'ATEloRatings', 'numbers', 'Avg_HST', 'Avg_AST'],
#       dtype='object')

# %%
cols = ['FTR',
       'HomeTeamLP', 'AwayTeamLP', 'HTFormPts', 'ATFormPts',
       'HTEloRatings', 'ATEloRatings', 'numbers', 'Avg_HST', 'Avg_AST']

df = df[cols]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df["FTR"] = LabelEncoder.fit_transform(df,df["FTR"])
# Out:
# C:\Users\pudur\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:117: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.classes_, y = _unique(y, return_inverse=True)
# C:\Users\pudur\AppData\Local\Temp\ipykernel_25052\2936863667.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FTR"] = LabelEncoder.fit_transform(df,df["FTR"])

# %%
X = df.drop(["FTR"],axis= 1)
X = X.values
y = df["FTR"]
y = y.values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
# !pip install xgboost
import xgboost as xgb

# %%
# model = xgb.XGBClassifier(n_estimators = 1000,use_label_encoder = True,max_depth =4,learning_rate = 0.09,gamma = 1,min_child_weight = 0.1,subsample=0.8,colsample_bytree=0.8,colsample_bylevel=0.8,colsample_bynode=0.8)

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from xgboost import XGBClassifier
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5],
        'learning_rate':[0.03,0.05,0.07,0.09,0.12,0.21],
        'n_estimators':[400,500,600,700,800,1000,1200,1500],
        'max_delta_step' :[0,1],
        'colsample_bynode' :[0,0.5,0.8]
        }
xgb_model = XGBClassifier()
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

random_search=RandomizedSearchCV(xgb_model,param_distributions=params,n_iter=10,scoring='roc_auc',n_jobs=10,cv=10,verbose=True)
from datetime import datetime
# Here we go
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X_train,y_train)
timer(start_time) # timing ends here for "start_time" variable

# %%
random_search.best_params_

# %%
random_search.best_estimator_

# %%
model = xgb.XGBClassifier(n_estimators = 1500,use_label_encoder = True,max_depth =4,learning_rate = 0.12,gamma = 1,min_child_weight = 10,max_delta_step = 1,subsample=0.6,colsample_bytree=0.8,colsample_bynode=0.8)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\pudur\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [07:21:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=0.8, colsample_bytree=0.8,
#               enable_categorical=False, gamma=1, gpu_id=-1,
# ...

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      1022
#            1       0.97      0.88      0.92       949
#            2       0.92      0.97      0.95      1738
#
#     accuracy                           0.94      3709
#    macro avg       0.94      0.93      0.94      3709
# weighted avg       0.94      0.94      0.94      3709

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.48      0.51       287
#            1       0.29      0.25      0.27       208
#            2       0.61      0.71      0.66       433
#
#     accuracy                           0.53       928
#    macro avg       0.48      0.48      0.48       928
# weighted avg       0.52      0.53      0.52       928

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
X.shape
# Out:
# (4637, 9)

# %%
y.shape
# Out:
# (4637,)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
kfold = KFold(n_splits=20)

model = xgb.XGBClassifier(n_estimators = 1500,use_label_encoder = True,max_depth =4,learning_rate = 0.12,gamma = 1,min_child_weight = 10,max_delta_step = 1,subsample=0.6,colsample_bytree=0.8,colsample_bynode=0.8)
results = cross_val_score(model,X,y,cv = kfold)
# Out:
# [07:25:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:25:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:25:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(results.mean())
# Out:
# 0.5031236005373937
